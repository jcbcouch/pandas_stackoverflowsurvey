# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')

# %%
df.shape
# Out:
# (65437, 113)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65437 entries, 1 to 65437
# Columns: 113 entries, MainBranch to JobSat
# dtypes: float64(13), object(100)
# memory usage: 56.9+ MB

# %%
pd.set_option('display.max_columns', 114)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')
schema_df.set_index('qname', inplace=True)

# %%
pd.set_option('display.max_rows', 87)

# %%
schema_df.shape
# Out:
# (87, 5)

# %%
df.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
# 9                                 I code primarily as a hobby
# 10                             I am a developer by profession
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 2              35-44 years old
# 3              45-54 years old
# 4              18-24 years old
# 5              18-24 years old
# 6           Under 18 years old
# ...

# %%
df.tail(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 65428       I am not primarily a developer, but I write co...
# 65429                          I am a developer by profession
# 65430                                   I am learning to code
# 65431                                   I am learning to code
# 65432                          I am a developer by profession
# 65433                          I am a developer by profession
# 65434                          I am a developer by profession
# 65435                          I am a developer by profession
# 65436                          I am a developer by profession
# 65437                             I code primarily as a hobby
#
#                         Age  \
# ResponseId
# 65428       25-34 years old
# 65429       25-34 years old
# 65430       18-24 years old
# 65431       18-24 years old
# 65432       45-54 years old
# 65433       18-24 years old
# 65434       25-34 years old
# ...

# %%
df['Age']
# Out:
# ResponseId
# 1        Under 18 years old
# 2           35-44 years old
# 3           45-54 years old
# 4           18-24 years old
# 5           18-24 years old
#                 ...
# 65433       18-24 years old
# 65434       25-34 years old
# 65435       25-34 years old
# 65436       18-24 years old
# 65437       18-24 years old
# Name: Age, Length: 65437, dtype: object

# %%
df[['Age', 'RemoteWork']]
# Out:
#                            Age                            RemoteWork
# ResponseId
# 1           Under 18 years old                                Remote
# 2              35-44 years old                                Remote
# 3              45-54 years old                                Remote
# 4              18-24 years old                                   NaN
# 5              18-24 years old                                   NaN
# ...                        ...                                   ...
# 65433          18-24 years old                                Remote
# 65434          25-34 years old                                Remote
# 65435          25-34 years old                             In-person
# 65436          18-24 years old  Hybrid (some remote, some in-person)
# 65437          18-24 years old                                   NaN
#
# [65437 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=113)

# %%
df.iloc[0]
# Out:
# MainBranch             I am a developer by profession
# Age                                Under 18 years old
# Employment                        Employed, full-time
# RemoteWork                                     Remote
# Check                                          Apples
#                                     ...
# JobSatPoints_11                                   NaN
# SurveyLength                                      NaN
# SurveyEase                                        NaN
# ConvertedCompYearly                               NaN
# JobSat                                            NaN
# Name: 1, Length: 113, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
#
#                                                  EdLevel  \
# ResponseId
# 1                              Primary/elementary school
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                      Books / Physical media
# ...

# %%
df.iloc[[0,1], 1]
# Out:
# ResponseId
# 1    Under 18 years old
# 2       35-44 years old
# Name: Age, dtype: object

# %%
df.iloc[[0,1], [1,2,3]]
# Out:
#                            Age           Employment RemoteWork
# ResponseId
# 1           Under 18 years old  Employed, full-time     Remote
# 2              35-44 years old  Employed, full-time     Remote

# %%
df.loc[[1,2,3], ['Employment', 'Age']]
# Out:
#                      Employment                 Age
# ResponseId
# 1           Employed, full-time  Under 18 years old
# 2           Employed, full-time     35-44 years old
# 3           Employed, full-time     45-54 years old

# %%
df.loc[1:5, 'Age':'LearnCode']
# Out:
#                            Age           Employment RemoteWork   Check  \
# ResponseId
# 1           Under 18 years old  Employed, full-time     Remote  Apples
# 2              35-44 years old  Employed, full-time     Remote  Apples
# 3              45-54 years old  Employed, full-time     Remote  Apples
# 4              18-24 years old   Student, full-time        NaN  Apples
# 5              18-24 years old   Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# ...

# %%
schema_df.loc['Webframe', 'question']
# Out:
# 'Which <b>web frameworks and web technologies</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)'

# %%
schema_df.sort_index(ascending=True, inplace=True)
